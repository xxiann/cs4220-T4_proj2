# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
# load training dataset
with open('datasets/train.dataset.6mer.npy', 'rb') as open_file:
    df = np.load(open_file)
df = pd.DataFrame(df)

# %%
labels = pd.read_csv('datasets/train_labels.csv')

# snippet to load the grouth truth training labels and normalize the label predictions. 
# your trained model will predict in this space (31 classes - pathogens and decoy)
le = preprocessing.LabelEncoder()
le.fit(labels['genome_name'].unique())
y_index = le.transform(labels['genome_name'].values)

# use index as train labels
df['genome_label'] = y_index

# %%
df['genome_label'].value_counts()
# Out:
# 7     424388
# 1       3787
# 16      3342
# 8       3166
# 13      2999
# 9       2840
# 19      2832
# 3       2715
# 18      2594
# 17      2578
# 30      2404
# 23      2388
# 12      2354
# 4       2248
# 0       2124
# 10      1801
# 29      1738
# 11      1576
# 28      1561
# 20      1489
# 21      1376
# 6       1306
# 5       1274
# 15      1194
# 25      1182
# 14      1150
# 27      1128
# 24      1092
# 26      1047
# 22       942
# 2        910
# Name: genome_label, dtype: int64

# %%
df.head()
# Out:
#           3         9        10        11        13        14        15  \
# 0  0.000823  0.001646  0.000823  0.002470  0.000411  0.001235  0.000000
# 1  0.001558  0.001039  0.001299  0.000779  0.000779  0.000779  0.000779
# 2  0.001851  0.000617  0.001234  0.000000  0.000617  0.001234  0.001851
# 3  0.001378  0.001378  0.000276  0.003859  0.001102  0.001102  0.000000
# 4  0.001701  0.001440  0.001178  0.001047  0.001047  0.001178  0.000785
#
#          18        19        22  ...      2071  2072  2073      2074  \
# 0  0.001235  0.001235  0.000411  ...  0.000000   0.0   0.0  0.000000
# 1  0.000779  0.002077  0.002077  ...  0.000519   0.0   0.0  0.000519
# 2  0.002468  0.000617  0.001851  ...  0.000000   0.0   0.0  0.000000
# 3  0.001378  0.001102  0.002756  ...  0.000000   0.0   0.0  0.000000
# 4  0.000916  0.002487  0.001571  ...  0.000000   0.0   0.0  0.000262
#
#        2075  2076  2077  2078  2079  genome_label
# 0  0.000000   0.0   0.0   0.0   0.0            20
# 1  0.000260   0.0   0.0   0.0   0.0            20
# 2  0.000000   0.0   0.0   0.0   0.0            20
# 3  0.000000   0.0   0.0   0.0   0.0            20
# 4  0.000131   0.0   0.0   0.0   0.0            20
#
# [5 rows x 1919 columns]

# %%
df.shape
# Out:
# (62924, 1919)

# %% [markdown]
# Remove samples with total k-mer count < 0.9

# %%
total_kmers = df.iloc[:, :-1].sum(axis=1)
df = df.loc[total_kmers >= 0.9, :]
y_index = y_index[total_kmers >= 0.9]

# %% [markdown]
# Downsample decoys

# %%
downsampled = df[df['genome_label'] == 7].sample(420601, random_state=4)
downsampled.index
# Out:
# Int64Index([415385, 276717, 301096,  88285,  15499, 377950, 329334, 425205,
#              90461, 477715,
#             ...
#              94812, 381037, 167116, 117181, 139215, 154100, 240125, 385251,
#             431883, 105292],
#            dtype='int64', length=420601)

# %%
df.drop(index=downsampled.index, inplace=True)

# %% [markdown]
# Remove columns with high correlation

# %%
mask = np.triu(np.ones_like(df.corr(), dtype=bool)) # remove duplicate upper triangle correlation values
corr_matrix = df.corr().abs() # create positive correlation matrix
tri_df = corr_matrix.mask(mask) # create and apply upper triangle mask

# %%
high_corr = [c for c in tri_df.columns if any(tri_df[c] > 0.7)]
len(high_corr)
# Out:
# 162

# %%
df.drop(columns=high_corr, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/61/_1tynjrd31972whvq0rhfvmc0000gn/T/ipykernel_10910/809209129.py in <module>
# ----> 1 df_red = df.drop(columns=high_corr, inplace=False)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: '[0 1 2 4 5 6 7 8 12 16 17 20 21 24 28 32 36 48 64 65 68 69 80 81 84 127\n 189 250 251 254 265 266 267 269 280 310 311 314 325 326 328 427 441 465\n 468 484 513 644 647 658 684 687 688 743 813 815 827 840 850 851 853 888\n 890 891 904 905 907 916 952 987 999 1090 1091 1112 1139 1147 1148 1149\n 1152 1155 1246 1248 1373 1375 1391 1392 1393 1403 1404 1411 1490 1491\n 1499 1508 1509 1514 1515 1516 1517 1605 1612 1642 1643 1664 1665 1666\n 1671 1746 1752 1771 1772 1818 1820 1845 1846 1847 1852 1858 1859 1861\n 1862 1863 1864 1865 1866 1867 1868 1869 1883 1884 1888 1889 1902 1903\n 1906 1907 1912 1916 1918 1920 1921 1922 1923 1924 1925 1926 1929 1934\n 1935 1937 1938 1939 1987 1998 2000 2031 2041 2049 2050 2056 2062 2063] not found in axis'

# %%
df.to_csv('pre_svd.csv', index=False)

# %%
df = pd.read_csv('pre_svd.csv')

# %% [markdown]
# Feature extraction using tSVD

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=500, random_state=4)
svd.fit(df.iloc[:, :-1].values)
# Out:
# TruncatedSVD(n_components=500, random_state=4)

# %%
import pickle as pk
pk.dump(svd, open('transformers/svd.pkl', 'wb'))

# %%
import pickle as pk
svd = pk.load(open('transformers/svd.pkl', 'rb'))

# %% [markdown]
# Subsample training set and perform dimensionality reduction

# %%
df_train = df.groupby('genome_label').apply(lambda x: x.sample(910, random_state=4))
X_train = svd.transform(df_train.iloc[:, :-1].values)
y_train = df_train['genome_label'].astype(int).values

# %%
X_train
# Out:
# array([[ 2.16119806e-02, -1.12246967e-02,  3.10852930e-04, ...,
#          1.48419513e-04, -3.78807179e-04, -2.21491643e-04],
#        [ 2.18505849e-02, -1.15034471e-02,  1.63952861e-03, ...,
#          2.48144278e-04,  6.19929214e-04, -2.66408205e-04],
#        [ 2.15662925e-02, -9.79539106e-03,  7.32436260e-04, ...,
#          3.93659798e-04, -9.01028979e-05, -6.77395971e-05],
#        ...,
#        [ 2.17961952e-02, -5.53790644e-03, -2.73646639e-03, ...,
#          5.97028994e-04, -4.89305601e-05,  1.07936952e-04],
#        [ 2.26182567e-02, -1.38002959e-03, -4.36690458e-03, ...,
#         -2.82249076e-04, -1.28196469e-05, -3.08790280e-05],
#        [ 2.21711476e-02, -2.21356876e-03, -4.22842009e-03, ...,
#          2.35392374e-04, -5.13989618e-04, -2.91539009e-04]])

# %%
df_train
# Out:
#                            3         9        10        11        13  \
# genome_label
# 0            34420  0.003378  0.001987  0.000199  0.002783  0.001590
#              32679  0.001767  0.001632  0.000816  0.001224  0.001767
#              33660  0.001410  0.000846  0.000564  0.001974  0.002115
#              34726  0.001965  0.002321  0.000535  0.001071  0.002142
#              32832  0.000804  0.001608  0.000804  0.002813  0.000000
# ...                      ...       ...       ...       ...       ...
# 30           57745  0.001081  0.000480  0.000360  0.000480  0.000960
#              57330  0.000887  0.000127  0.000253  0.000380  0.000634
#              58178  0.000985  0.001232  0.000000  0.000739  0.000246
#              57039  0.001042  0.000651  0.000261  0.000521  0.000521
#              57340  0.001428  0.000408  0.000000  0.001224  0.000204
#
#                           14        15        18        19        22  ...  \
# genome_label                                                          ...
# 0            34420  0.001391  0.001391  0.001391  0.001391  0.000795  ...
#              32679  0.000544  0.001495  0.001359  0.000544  0.001495  ...
#              33660  0.001410  0.001268  0.000564  0.000846  0.000987  ...
#              34726  0.000893  0.001965  0.000893  0.001785  0.001250  ...
#              32832  0.001205  0.002010  0.000804  0.000000  0.002010  ...
# ...                      ...       ...       ...       ...       ...  ...
# 30           57745  0.000480  0.000840  0.001560  0.000840  0.000480  ...
#              57330  0.000760  0.000380  0.000380  0.000253  0.000760  ...
#              58178  0.000493  0.000739  0.000739  0.000985  0.000739  ...
#              57039  0.000782  0.001564  0.000782  0.000782  0.000782  ...
#              57340  0.000816  0.000612  0.000204  0.000816  0.000408  ...
#
#                         2071      2072      2073      2074      2075  \
# genome_label
# 0            34420  0.000795  0.000000  0.000596  0.000000  0.000000
#              32679  0.000000  0.000136  0.000272  0.000000  0.000000
#              33660  0.000000  0.000000  0.000282  0.000000  0.000141
#              34726  0.000000  0.000000  0.000535  0.000000  0.000000
#              32832  0.000804  0.000000  0.000402  0.000000  0.000000
# ...                      ...       ...       ...       ...       ...
# 30           57745  0.000240  0.000480  0.000840  0.000000  0.000480
#              57330  0.000253  0.000127  0.000634  0.000000  0.000507
#              58178  0.000000  0.000246  0.000246  0.000000  0.000246
#              57039  0.000521  0.000130  0.001173  0.000261  0.000391
#              57340  0.000000  0.000000  0.000408  0.000000  0.000204
#
#                         2076      2077      2078  2079  genome_label
# genome_label
# 0            34420  0.000000  0.000000  0.000000   0.0             0
#              32679  0.000000  0.000000  0.000000   0.0             0
#              33660  0.000000  0.000000  0.000000   0.0             0
#              34726  0.000000  0.000000  0.000357   0.0             0
#              32832  0.000000  0.000000  0.000000   0.0             0
# ...                      ...       ...       ...   ...           ...
# 30           57745  0.000360  0.000240  0.000000   0.0            30
#              57330  0.000127  0.000127  0.000000   0.0            30
#              58178  0.000000  0.000000  0.000493   0.0            30
#              57039  0.000130  0.000261  0.000000   0.0            30
#              57340  0.000408  0.000204  0.000408   0.0            30
#
# [28210 rows x 1919 columns]

# %% [markdown]
# Train SVM model

# %%
from sklearn.calibration import CalibratedClassifierCV
from sklearn.svm import SVC
from joblib import dump, load
svm = SVC(C=10, kernel='rbf', gamma=10, probability=False, random_state=4)
model = CalibratedClassifierCV(svm, method='sigmoid', cv=5) # wrap the SVM classifier in a CalibratedClassifierCV instance
model.fit(X_train, y_train)
# Out:
# CalibratedClassifierCV(base_estimator=SVC(C=10, gamma=10, random_state=4), cv=5)

# %%
dump(model, 'models/svm.joblib')
# Out:
# ['models/svm.joblib']

# %%
from joblib import load
model = load('models/svm.joblib')

# %% [markdown]
# Predictions

# %%
def precision_per_patient(patient_id, preds):
    df_true = pd.read_csv(f'datasets/validation/patient{patient_id}_labels.txt')
    tp, fp, tp_labels = 0, 0, df_true['true_label'].shape[0]
    print(f'my prediction(s) for patient {patient_id}: {preds}')
    truth = df_true['true_label'].values
    print(f'true pathogen(s): {truth}')
    #if don't predict any pathogen, it means there is only decoy in the test dataset (your prediction)
    if len(preds) == 0:
        preds = ['decoy']
    for item in np.unique(preds):
        if item in df_true['true_label'].values:
            tp+=1
        else:
            fp+=1
    #you have to predict all labels correctly, but you are penalized for any false positive
    return tp/(tp_labels+fp)

# %%
with open(f'datasets/validation/patient1.6mer.npy', 'rb') as read_file:
    df_test = np.load(read_file)
df_test = pd.DataFrame(df_test)
df_test
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.000655  0.003929  0.001309  0.001528  0.002401  0.003492  0.001965
# 1     0.001521  0.000869  0.003042  0.001304  0.001304  0.000652  0.000652
# 2     0.001271  0.003496  0.000636  0.001271  0.002224  0.002542  0.003813
# 3     0.002781  0.002411  0.001483  0.000927  0.002781  0.001854  0.001669
# 4     0.001933  0.003410  0.001478  0.001592  0.003639  0.003298  0.003071
# ...        ...       ...       ...       ...       ...       ...       ...
# 9993  0.001433  0.002867  0.001433  0.000358  0.002867  0.003225  0.002867
# 9994  0.008995  0.003229  0.001384  0.000923  0.003229  0.001384  0.001615
# 9995  0.004356  0.001452  0.001816  0.002905  0.002542  0.001089  0.003267
# 9996  0.000876  0.000876  0.002628  0.000000  0.001753  0.000000  0.000876
# 9997  0.004841  0.001760  0.003080  0.001321  0.003521  0.002201  0.002201
#
#           7         8         9     ...      2070      2071      2072  \
# 0     0.000655  0.000873  0.001091  ...  0.000218  0.000873  0.000000
# 1     0.001521  0.002172  0.001304  ...  0.000000  0.000000  0.000000
# 2     0.000953  0.001271  0.000953  ...  0.000000  0.000636  0.000000
# 3     0.000556  0.002039  0.000741  ...  0.000000  0.000741  0.000000
# 4     0.001592  0.001137  0.001250  ...  0.000114  0.000227  0.000000
# ...        ...       ...       ...  ...       ...       ...       ...
# 9993  0.001433  0.002151  0.000358  ...  0.000358  0.000717  0.001076
# 9994  0.001153  0.000461  0.001384  ...  0.000692  0.000000  0.000461
# 9995  0.000363  0.001452  0.001452  ...  0.000363  0.000726  0.000726
# 9996  0.001753  0.000000  0.003506  ...  0.000876  0.003506  0.001753
# 9997  0.001321  0.002201  0.001760  ...  0.000440  0.000000  0.000000
#
#           2073      2074      2075      2076  2077      2078      2079
# 0     0.000000  0.000437  0.000000  0.000000   0.0  0.000000  0.000000
# 1     0.000217  0.000434  0.000000  0.000000   0.0  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  0.000000   0.0  0.000000  0.000000
# 3     0.000000  0.000000  0.000371  0.000000   0.0  0.000000  0.000000
# 4     0.000114  0.000000  0.000000  0.000000   0.0  0.000000  0.000000
# ...        ...       ...       ...       ...   ...       ...       ...
# 9993  0.000000  0.000717  0.000000  0.000000   0.0  0.000000  0.000000
# 9994  0.000000  0.000461  0.001153  0.000231   0.0  0.000461  0.000461
# 9995  0.000363  0.000000  0.000726  0.000000   0.0  0.000000  0.000000
# 9996  0.000876  0.000000  0.001753  0.000000   0.0  0.000000  0.000000
# 9997  0.000000  0.000880  0.000000  0.000000   0.0  0.000000  0.000000
#
# [9998 rows x 2080 columns]

# %%
feat = df_train.columns[:-1].values.astype(int)

# %%
len(feat)
# Out:
# 1918

# %%
import time

def predict(prob_threshold, read_threshold, model, transformer):
    start = time.time()

    all_precision = []
    for patient_id in range(1, 11):
        print(f'predicting for patient {patient_id}')
        
        with open(f'datasets/validation/patient{patient_id}.6mer.npy', 'rb') as read_file:
            df_test = np.load(read_file)
        df_test = pd.DataFrame(df_test)
        X_test = transformer.transform(df_test.loc[:, feat].values)

        # we can use model.predict_proba to find a good threshold and predict only for cases where the model is confident
        y_predprob = model.predict_proba(X_test) # probability of each class per read
        
        # we get only predictions larger than the threshold and if there is more than one, we take the argmax again
        # num_reads = X_test.shape[0]
        predictions_count = {}
        for read in y_predprob:
            if np.max(read) >= prob_threshold:
                label = np.argmax(read)
                if label in predictions_count:
                    predictions_count[label] += 1
                else:
                    predictions_count[label] = 1
        print(predictions_count)
        final_predictions = le.inverse_transform([label for label, count in predictions_count.items() if count > read_threshold]) # only consider labels with more than 5 reads predicting that label, can change to % num_reads
        
        # my pathogens detected, decoy will be ignored
        final_predictions = [item for item in final_predictions if item !='decoy']
        
        precision = precision_per_patient(patient_id, final_predictions)
        print(f'precision: {precision}')
        all_precision.append(precision)

    # performance per patient and its final average
    print([f'patient {c}: {item}' for c, item in enumerate(all_precision, start=1)])
    print(f'avg: {np.mean(all_precision)}')

    end = time.time()
    print(f'Time taken for prediction: {end - start} seconds')

predict(0.8, 5, model, svd)
# Out:
# predicting for patient 1
# {1: 52, 5: 6, 16: 4, 11: 64, 7: 2445}
# my prediction(s) for patient 1: ['burkholderia_pseudomallei', 'corynebacterium_diphtheriae', 'listeria_monocytogenes']
# true pathogen(s): ['staphylococcus_aureus']
# precision: 0.0
# predicting for patient 2
# {22: 39, 29: 6, 25: 4, 6: 9, 0: 4, 5: 72, 4: 3, 11: 455, 21: 5, 20: 6, 10: 8, 1: 482, 16: 5, 13: 15, 27: 3, 26: 1, 24: 1, 7: 881}
# my prediction(s) for patient 2: ['staphylococcus_pyogenes', 'vibrio_parahaemolyticus', 'corynebacterium_ulcerans', 'corynebacterium_diphtheriae', 'listeria_monocytogenes', 'staphylococcus_aureus', 'legionella_pneumophila', 'burkholderia_pseudomallei', 'mycobacterium_ulcerans']
# true pathogen(s): ['staphylococcus_pyogenes']
# precision: 0.1111111111111111
# predicting for patient 3
# {1: 136, 5: 17, 16: 3, 13: 3, 6: 8, 11: 867, 10: 11, 22: 7, 0: 5, 21: 7, 27: 3, 26: 3, 24: 3, 7: 1392}
# my prediction(s) for patient 3: ['burkholderia_pseudomallei', 'corynebacterium_diphtheriae', 'corynebacterium_ulcerans', 'listeria_monocytogenes', 'legionella_pneumophila', 'staphylococcus_pyogenes', 'staphylococcus_pseudintermedius']
# true pathogen(s): ['burkholderia_pseudomallei' 'corynebacterium_ulcerans']
# precision: 0.2857142857142857
# predicting for patient 4
# {16: 7, 5: 2, 13: 15, 6: 1, 11: 241, 22: 1, 10: 7, 27: 3, 21: 2, 30: 1, 20: 2, 29: 1, 7: 1131}
# my prediction(s) for patient 4: ['pseudomonas_aeruginosa', 'mycobacterium_ulcerans', 'listeria_monocytogenes', 'legionella_pneumophila']
# true pathogen(s): ['pseudomonas_aeruginosa']
# precision: 0.25
# predicting for patient 5
# {5: 15, 11: 37, 22: 1, 7: 2456, 16: 2}
# my prediction(s) for patient 5: ['corynebacterium_diphtheriae', 'listeria_monocytogenes']
# true pathogen(s): ['corynebacterium_diphtheriae']
# precision: 0.5
# predicting for patient 6
# {29: 1, 10: 1, 7: 2260, 16: 1}
# my prediction(s) for patient 6: []
# true pathogen(s): ['streptococcus_pneumoniae']
# precision: 0.0
# predicting for patient 7
# {13: 464, 5: 739, 6: 155, 12: 13, 23: 2, 7: 1254}
# my prediction(s) for patient 7: ['mycobacterium_ulcerans', 'corynebacterium_diphtheriae', 'corynebacterium_ulcerans', 'mycobacterium_tuberculosis']
# true pathogen(s): ['mycobacterium_ulcerans']
# precision: 0.25
# predicting for patient 8
# {7: 2629, 16: 2}
# my prediction(s) for patient 8: []
# true pathogen(s): ['mycobacterium_tuberculosis' 'streptococcus_pneumoniae']
# precision: 0.0
# predicting for patient 9
# {13: 4, 16: 2, 11: 119, 22: 2, 10: 9, 27: 2, 21: 2, 5: 1, 30: 1, 7: 1990}
# my prediction(s) for patient 9: ['listeria_monocytogenes', 'legionella_pneumophila']
# true pathogen(s): ['streptococcus_pneumoniae']
# precision: 0.0
# predicting for patient 10
# {1: 215, 21: 2, 11: 182, 20: 1, 5: 27, 16: 6, 13: 5, 6: 3, 10: 2, 22: 1, 0: 2, 27: 1, 7: 2126}
# my prediction(s) for patient 10: ['burkholderia_pseudomallei', 'listeria_monocytogenes', 'corynebacterium_diphtheriae', 'pseudomonas_aeruginosa']
# true pathogen(s): ['burkholderia_pseudomallei']
# precision: 0.25
# ['patient 1: 0.0', 'patient 2: 0.1111111111111111', 'patient 3: 0.2857142857142857', 'patient 4: 0.25', 'patient 5: 0.5', 'patient 6: 0.0', 'patient 7: 0.25', 'patient 8: 0.0', 'patient 9: 0.0', 'patient 10: 0.25']
# avg: 0.16468253968253968
# Time taken for prediction: 4518.304705142975 seconds
